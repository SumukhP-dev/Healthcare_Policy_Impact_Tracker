# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os

# %%
# Load Mortality Dataset
mortality_datatset = pd.read_csv('/content/cleaned_2016-2023-imi-results-long-view.csv')
dataset_start_year = 2016
dataset_end_year = 2023

mortality_datatset.describe()
# Out:
#               YEAR   # of Deaths     # of Cases
# count   365.000000    365.000000     365.000000
# mean   2018.849315    750.408219   15219.709589
# std       1.930604   1640.673599   33592.503271
# min    2016.000000      0.000000      14.000000
# 25%    2017.000000     26.000000     732.000000
# 50%    2019.000000    160.000000    4044.000000
# 75%    2020.000000    777.000000   15702.000000
# max    2022.000000  13858.000000  259784.000000

# %%
# Load Mortality Dataset
mortality_datatset = pd.read_csv('/content/cleaned_2016-2023-imi-results-long-view.csv')

# Specify the directory name
directory_name = "mortality_datatset"

previous_year_value = None

# Create the directory
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except PermissionError:
    print(f"Permission denied: Unable to create '{directory_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")


# Drop the # of Cases column
mortality_datatset.drop(columns=['# of Cases'], inplace=True)

# 2019 Law - Medi-Cal expansions for all income-eligible young adults, regardless of immigration status
law_start_year = 2019

# Adding D (Intervention) column values for each row as the law was introduced in 2019
for index, row in mortality_datatset.iterrows():
  if (row['YEAR'] >= law_start_year):
    mortality_datatset.at[index, 'D'] = 1
  elif (row['YEAR'] == (law_start_year - 1)):
    previous_year_value = row["# of Deaths"]
    mortality_datatset.at[index, 'D'] = 0
  else:
    mortality_datatset.at[index, 'D'] = 0


# Renaming column # of Deaths to Y
mortality_datatset.rename(columns={'# of Deaths': 'Y'}, inplace=True)

# Seperate main csv file into csv files for each county
for county, group in mortality_datatset.groupby(['COUNTY']):
  # Remove County column
  group.drop(columns=['COUNTY'], inplace=True)

  # Remove Year column
  group.drop(columns=['YEAR'], inplace=True)

  # Adding T (Year) column values for each row
  group.insert(0, 'T', range(1, group['D'].size + 1))

  intervention_year_index = 1

  # Adding P (Intervention Year) column values for each row
  for index, row in group.iterrows():
    if (row['D'] == 1):
      group.at[index, 'P'] = intervention_year_index
      intervention_year_index += 1
    else:
      group.at[index, 'P'] = 0

  group.to_csv(f'mortality_datatset/{county[0]}.csv', index=False)
# Out:
# Directory 'mortality_datatset' already exists.

# %%
from statsmodels.tsa.arima.model import ARIMA
import scipy as sp
from statsmodels.graphics.gofplots import qqplot
import matplotlib.pyplot as plt

# %%
path = 'mortality_datatset'
dfs = []
output_dfs = []
df_names = []
final_dfs = []

# Specify the directory name
directory_name = "mortality_2019_medi_cal_expansions"

# Create the directory
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except PermissionError:
    print(f"Permission denied: Unable to create '{directory_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")

# Specify the directory name
directory_name = "mortality_2019_medi_cal_expansions/datasets"

# Create the directory
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except PermissionError:
    print(f"Permission denied: Unable to create '{directory_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")

# Specify the directory name
directory_name = "mortality_2019_medi_cal_expansions/charts"

# Create the directory
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except PermissionError:
    print(f"Permission denied: Unable to create '{directory_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")

# Specify the directory name
directory_name = "mortality_2019_medi_cal_expansions/final_datasets"

# Create the directory
try:
    os.mkdir(directory_name)
    print(f"Directory '{directory_name}' created successfully.")
except FileExistsError:
    print(f"Directory '{directory_name}' already exists.")
except PermissionError:
    print(f"Permission denied: Unable to create '{directory_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")

for f in os.listdir(path):
  if f.endswith('.csv'):
    dfs.append(pd.read_csv(f'mortality_datatset/{f}'))
    df_names.append(f.removesuffix(".csv"))
# Out:
# Directory 'mortality_2019_medi_cal_expansions' already exists.
# Directory 'mortality_2019_medi_cal_expansions/datasets' already exists.
# Directory 'mortality_2019_medi_cal_expansions/charts' already exists.
# Directory 'mortality_2019_medi_cal_expansions/final_datasets' already exists.

# %%
first = True
dataframe_counter = 0

for df in dfs:
  arima_results = ARIMA(df["Y"], df[["T","D","P"]], order=(1,0,0)).fit()

  start = -1
  end = -1

  for index, row in df.iterrows():
    if row["D"] == 1 and start == -1:
      start = index

  end = df.shape[0]

  predictions = arima_results.get_prediction(0, end-1)
  summary = predictions.summary_frame(alpha=0.05)

  arima_cf = ARIMA(df["Y"][:start], df["T"][:start], order=(1,0,0)).fit()

  # Model predictions means
  y_pred = predictions.predicted_mean

  # Counterfactual mean and 95% confidence interval
  y_cf = arima_cf.get_forecast(end - start, exog=df["T"][start:]).summary_frame(alpha=0.05)

  # Plot section
  fig, ax = plt.subplots()

  # Plot bounce rate data
  ax.scatter(df["T"], df["Y"], facecolors='none', edgecolors='steelblue', label="# of Deaths data", linewidths=2)

  # Plot model mean bounce prediction
  ax.plot(df["T"][:start], y_pred[:start], 'b-', label="model prediction")
  ax.plot(df["T"][start:], y_pred[start:], 'b-')

  # Plot counterfactual mean bounce rate with 95% confidence interval
  ax.plot(df["T"][start:], y_cf["mean"], 'k.', label="counterfactual")
  ax.fill_between(df["T"][start:], y_cf['mean_ci_lower'], y_cf['mean_ci_upper'], color='k', alpha=0.1, label="counterfactual 95% CI")


  # Plot line marking intervention moment
  ax.axvline(x = start, color = 'r', label = 'intervention')

  ax.legend(loc='best')
  plt.ylim()
  plt.xlabel("Year")
  plt.ylabel("# of Deaths")

  if first:
    print(df_names[0])
    print(arima_results.summary())
    plt.show()
    first = False

  plt.savefig(f'mortality_2019_medi_cal_expansions/charts/{df_names[dataframe_counter]}.png')
  plt.close()

  predictions_dataset = y_pred[start:]

  output_dfs.append(predictions_dataset.to_frame())
  predictions_dataset.to_csv(f'mortality_2019_medi_cal_expansions/datasets/{df_names[dataframe_counter]}.csv', index=False)



  predictions_dataset = predictions_dataset.to_frame()

  predictions_dataset.loc[-1] = previous_year_value
  predictions_dataset.sort_index(inplace=True)

  predictions_dataset.insert(0, 'Years', range(law_start_year - 1, law_start_year + predictions_dataset['predicted_mean'].size - 1))

  final_dfs.append(predictions_dataset)

  dataframe_counter += 1
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Monterey
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      Y   No. Observations:                    7
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 -33.754
# Date:                Mon, 07 Jul 2025   AIC                             79.508
# Time:                        05:10:20   BIC                             79.184
# Sample:                             0   HQIC                            75.497
#                                   - 7
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        508.6942    193.650      2.627      0.009     129.147     888.241
# T            -45.2252     73.664     -0.614      0.539    -189.604      99.153
# D            302.5061     61.421      4.925      0.000     182.123     422.889
# P            -77.1327     83.869     -0.920      0.358    -241.513      87.247
# ar.L1         -0.8428      0.641     -1.315      0.189      -2.099       0.414
# sigma2       756.9093   2224.370      0.340      0.734   -3602.775    5116.594
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.55   Jarque-Bera (JB):                 0.30
# Prob(Q):                              0.03   Prob(JB):                         0.86
# Heteroskedasticity (H):               1.76   Skew:                            -0.44
# Prob(H) (two-sided):                  0.72   Kurtosis:                         2.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# !zip -r /content/mortality_2019_medi_cal_expansions/zipped_data /content/mortality_2019_medi_cal_expansions/datasets
# Out:
# updating: content/mortality_2019_medi_cal_expansions/datasets/ (stored 0%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Monterey.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Calaveras.csv (deflated 15%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Alameda.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Lassen.csv (deflated 19%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Luis Obispo.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Sonoma.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Siskiyou.csv (deflated 8%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Joaquin.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Orange.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Merced.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Santa Cruz.csv (deflated 10%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Kern.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Mendocino.csv (deflated 19%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Santa Barbara.csv (deflated 6%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Humboldt.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Stanislaus.csv (deflated 9%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Yuba.csv (deflated 8%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Madera.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Tulare.csv (deflated 9%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Placer.csv (deflated 15%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Santa Clara.csv (deflated 8%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Los Angeles.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Glenn.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Trinity.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/El Dorado.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Solano.csv (deflated 6%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Lake.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Mateo.csv (deflated 6%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Amador.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Shasta.csv (deflated 9%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Riverside.csv (deflated 14%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Colusa.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Mono.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Napa.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Tehama.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Contra Costa.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Tuolumne.csv (deflated 9%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Bernardino.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Imperial.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Nevada.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Francisco.csv (deflated 8%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Benito.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Marin.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Fresno.csv (deflated 15%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Mariposa.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Plumas.csv (deflated 15%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Ventura.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Kings.csv (deflated 18%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Modoc.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Butte.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Sacramento.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Yolo.csv (deflated 7%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Inyo.csv (deflated 17%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/Del Norte.csv (deflated 16%)
# updating: content/mortality_2019_medi_cal_expansions/datasets/San Diego.csv (deflated 18%)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns
sns.set_style(
    style='darkgrid',
    rc={'axes.facecolor': '.9', 'grid.color': '.8'}
)
sns.set_palette(palette='deep')
sns_c = sns.color_palette(palette='deep')
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100

# %%
from sklearn.gaussian_process.kernels import WhiteKernel, ExpSineSquared, ConstantKernel
from sklearn.gaussian_process import GaussianProcessRegressor

# %%
k0 = WhiteKernel(noise_level=0.3**2, noise_level_bounds=(0.1**2, 0.5**2))

k1 = ConstantKernel(constant_value=2) * \
  ExpSineSquared(length_scale=1.0, periodicity=40, periodicity_bounds=(35, 45))

kernel_1  = k0 + k1

# %%
gp1 = GaussianProcessRegressor(
    kernel=kernel_1,
    n_restarts_optimizer=10,
    normalize_y=True,
    alpha=0.0
)

# %%
dataframe_counter = 0

for data_df in output_dfs:
  data_df.rename(columns={'predicted_mean': 's1'}, inplace=True)

  # Define target variable.
  data_df['y1'] = data_df['s1']

  # Set noise standard deviation.
  sigma_n = 0.3

  n = data_df.shape[0]

  data_df['epsilon'] = np.random.normal(loc=0, scale=sigma_n, size=n)

  # Add noise to target variable.
  data_df ['y1'] = data_df ['y1'] + data_df ['epsilon']

  if 't' not in data_df.columns:
    data_df.insert(0, 't', range(0, data_df['y1'].size))

  data_df.reset_index(drop=True, inplace=True)

  X = data_df['t'].values.reshape(n, 1)
  y = data_df['y1'].values.reshape(n, 1)

  prop_train = 0.5
  n_train = round(prop_train * n)

  X_train = X[:n_train]
  y_train = y[:n_train]

  X_test = X[n_train:]
  y_test = y[n_train:]

  gp1_prior_samples = gp1.sample_y(X=X_train, n_samples=100)

  if dataframe_counter == 0:
    fig, ax = plt.subplots()
    for i in range(100):
        sns.lineplot(x=X_train[...,0], y = gp1_prior_samples[:, i], color=sns_c[1], alpha=0.2, ax=ax)
    sns.lineplot(x=X_train[...,0], y=y_train[..., 0], color=sns_c[0], label='y1', ax=ax)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.7))
    ax.set(title='GP1 Prior Samples', xlabel='t');

  gp1.fit(X_train, y_train)

  GaussianProcessRegressor(alpha=0.0,
                          kernel=WhiteKernel(noise_level=0.09) + 1.41**2 * ExpSineSquared(length_scale=1, periodicity=40),
                          n_restarts_optimizer=10, normalize_y=True)

  # Generate predictions.
  y_pred, y_std = gp1.predict(X, return_std=True)

  data_df['y_pred'] = y_pred
  data_df['y_std'] = y_std
  data_df['y_pred_lwr'] = data_df['y_pred'] - 2*data_df['y_std']
  data_df['y_pred_upr'] = data_df['y_pred'] + 2*data_df['y_std']

  if dataframe_counter == 0:
    fig, ax = plt.subplots()

    ax.fill_between(
        x=data_df['t'],
        y1=data_df['y_pred_lwr'],
        y2=data_df['y_pred_upr'],
        color=sns_c[2],
        alpha=0.15,
        label='credible_interval'
    )

    sns.lineplot(x='t', y='y1', data=data_df, color=sns_c[0], label = 'y1', ax=ax)
    sns.lineplot(x='t', y='y_pred', data=data_df, color=sns_c[2], label='y_pred', ax=ax)

    ax.axvline(n_train, color=sns_c[3], linestyle='--', label='train-test split')
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.7))
    ax.set(title='Prediction Sample 1', xlabel='t', ylabel='');

  num_of_predictions = 10
  X_predictions = []

  for i in range(num_of_predictions):
    X_predictions.append([i + 1])


  y_pred, y_std = gp1.predict(X_predictions, return_std=True)

  current_year = dataset_end_year
  new_df = pd.DataFrame()

  for i in range(num_of_predictions):
    new_df = pd.concat([new_df, (pd.DataFrame({'Years': [current_year], 'predicted_mean': [y_pred[i]]}))])
    current_year += 1

  df = pd.concat([final_dfs[dataframe_counter], new_df])
  df['% Change'] = df['predicted_mean'].pct_change() * 100

  df.to_csv(f'mortality_2019_medi_cal_expansions/final_datasets/{df_names[dataframe_counter]}.csv', index=False)

  dataframe_counter += 1
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__periodicity is close to the specified lower bound 35. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/gaussian_process/kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__noise_level is close to the specified upper bound 0.25. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
# !zip -r /content/mortality_2019_medi_cal_expansions/zipped_final_data /content/mortality_2019_medi_cal_expansions/final_datasets

# !zip -r /content/mortality_2019_medi_cal_expansions/zipped_charts /content/mortality_2019_medi_cal_expansions/charts
# Out:
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/ (stored 0%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Monterey.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Calaveras.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Alameda.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Lassen.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Luis Obispo.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Sonoma.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Siskiyou.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Joaquin.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Orange.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Merced.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Santa Cruz.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Kern.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Mendocino.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Santa Barbara.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Humboldt.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Stanislaus.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Yuba.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Madera.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Tulare.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Placer.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Santa Clara.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Los Angeles.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Glenn.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Trinity.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/El Dorado.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Solano.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/.ipynb_checkpoints/ (stored 0%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Lake.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Mateo.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Amador.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Shasta.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Riverside.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Colusa.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Mono.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Napa.csv (deflated 57%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Tehama.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Contra Costa.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Tuolumne.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Bernardino.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Imperial.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Nevada.csv (deflated 57%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Francisco.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/None (stored 0%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Benito.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Marin.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Fresno.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Mariposa.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Plumas.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Ventura.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Kings.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Modoc.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Butte.csv (deflated 59%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Sacramento.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Yolo.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Inyo.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/Del Norte.csv (deflated 58%)
# updating: content/mortality_2019_medi_cal_expansions/final_datasets/San Diego.csv (deflated 58%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/ (stored 0%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Marin.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Benito.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Trinity.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Mariposa.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Sonoma.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Glenn.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Francisco.png (deflated 14%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Ventura.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Sacramento.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Tehama.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Shasta.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Siskiyou.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Lassen.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Joaquin.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/El Dorado.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Colusa.png (deflated 15%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Amador.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Tuolumne.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Mendocino.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Calaveras.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Alameda.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Merced.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Kern.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Orange.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Kings.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Los Angeles.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Napa.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Inyo.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Santa Barbara.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Contra Costa.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Stanislaus.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Solano.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Mateo.png (deflated 14%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Imperial.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Nevada.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Mono.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Fresno.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Riverside.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Yuba.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Lake.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Bernardino.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Plumas.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Monterey.png (deflated 95%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Placer.png (deflated 10%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Modoc.png (deflated 14%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Santa Clara.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Del Norte.png (deflated 9%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Humboldt.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Madera.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Santa Cruz.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Butte.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Tulare.png (deflated 11%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Luis Obispo.png (deflated 13%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/Yolo.png (deflated 12%)
#   adding: content/mortality_2019_medi_cal_expansions/charts/San Diego.png (deflated 11%)
